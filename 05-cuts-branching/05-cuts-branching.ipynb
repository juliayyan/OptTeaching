# %% [markdown]
# # Lecture 5 - Cuts and Branching

# %% [markdown]
# ##  Header

# %%
# # Dependencies: Uncomment and run this cell if you don't have these packages 
# using Pkg
# Pkg.add("JuMP")
# Pkg.add("Gurobi")
# Pkg.add("Combinatorics")
# Pkg.add("Plots")

# %%
include("../01-tsp/src/data.jl");
include("../01-tsp/src/opt.jl");
include("../01-tsp/src/out.jl");
include("src/tracking.jl");

# %% [markdown]
# ## Setup

# %% [markdown]
# We are going to look at a Gurobi log for an instance of the MTZ formulation. Let us first generate instance data.

# %%
# One instance to deep-dive into each model
dat = TSPInstance(150, random_seed = 1)
# Out:
# TSP Instance with 150 cities

# %% [markdown]
# We'll use optimizers with cuts, without cuts, and with strong branching

# %%
optimizer_cuts = JuMP.optimizer_with_attributes(Gurobi.Optimizer, "TimeLimit" => 15)
optimizer_nocuts = JuMP.optimizer_with_attributes(Gurobi.Optimizer, "Cuts" => 0, "TimeLimit" => 15)
optimizer_branch = JuMP.optimizer_with_attributes(Gurobi.Optimizer, "VarBranch" => 3, "TimeLimit" => 15)
# Out:
# MathOptInterface.OptimizerWithAttributes(Gurobi.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.RawOptimizerAttribute("VarBranch") => 3, MathOptInterface.RawOptimizerAttribute("TimeLimit") => 15])

# %% [markdown]
# ## The effect of cutting planes

# %% [markdown]
# First, we turn off cutting planes and solve.

# %%
mdl_mtz = TSPModel(dat, optimizer = optimizer_nocuts)
add_mtz_constraints!(mdl_mtz)
add_tracking_callback!(mdl_mtz)
solve!(mdl_mtz)
plot_progress([mdl_mtz], ["No Cuts"])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-18
# Set parameter Cuts to value 0
# Set parameter TimeLimit to value 15
# Set parameter Cuts to value 0
# Set parameter TimeLimit to value 15
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.3.0 23D56)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 45301 rows, 22650 columns and 156455 nonzeros
# Model fingerprint: 0xde9bd251
# Variable types: 150 continuous, 22500 integer (22500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [5e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 11774 rows and 151 columns
# Presolve time: 0.20s
# Presolved: 33527 rows, 22499 columns, 133206 nonzeros
# Variable types: 149 continuous, 22350 integer (22350 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.022202e+00, 662 iterations, 0.07 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.02220    0  272          -    9.02220      -     -    0s
#      0     0    9.02932    0  272          -    9.02932      -     -    0s
#      0     2    9.02932    0  272          -    9.02932      -     -    3s
#    506   522    9.33720   54  256          -    9.04680      -  22.1    5s
#   3782  3829    9.37533  344  271          -    9.04680      -  17.5   10s
# H 3787  3829                      12.4677951    9.04680  27.4%  17.5   10s
# H 3805  3829                      12.2364994    9.04680  26.1%  17.6   10s
# H 3811  3829                      12.2270405    9.04680  26.0%  17.6   10s
# H 3827  3829                      12.0932883    9.04680  25.2%  17.6   10s
# H 3839  3829                      11.9422310    9.04680  24.2%  17.5   10s
# H 3846  3839                      11.3707206    9.04680  20.4%  17.5   12s
# H 3847  3839                      11.3256441    9.04680  20.1%  17.5   12s
# H 3848  3835                      11.2363203    9.04680  19.5%  17.5   12s
# H 3849  3831                      11.0623771    9.04680  18.2%  17.5   12s
# H 4018  3986                      10.6938006    9.04680  15.4%  17.5   15s
#
# Explored 4051 nodes (72166 simplex iterations) in 15.03 seconds (33.44 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 10.6938 11.0624 11.2363 ... 12.4678
#
# Time limit reached
# Best objective 1.069380064562e+01, best bound 9.046799189243e+00, gap 15.4015%
#
# User-callback calls 14089, time in user-callback 0.03 sec

# %% [markdown]
# Now, we turn cutting planes back on and solve.

# %%
mdl_mtz_2 = TSPModel(dat, optimizer = optimizer_cuts)
add_mtz_constraints!(mdl_mtz_2)
add_tracking_callback!(mdl_mtz_2)
solve!(mdl_mtz_2)
plot_progress([mdl_mtz, mdl_mtz_2], ["No Cuts", "Cuts"])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-18
# Set parameter TimeLimit to value 15
# Set parameter TimeLimit to value 15
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.3.0 23D56)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 45301 rows, 22650 columns and 156455 nonzeros
# Model fingerprint: 0xde9bd251
# Variable types: 150 continuous, 22500 integer (22500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [5e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 11774 rows and 151 columns
# Presolve time: 0.21s
# Presolved: 33527 rows, 22499 columns, 133206 nonzeros
# Variable types: 149 continuous, 22350 integer (22350 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.022202e+00, 662 iterations, 0.08 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.02220    0  272          -    9.02220      -     -    0s
# H    0     0                      21.1403326    9.04263  57.2%     -    0s
#      0     0    9.04263    0  333   21.14033    9.04263  57.2%     -    0s
# H    0     0                      12.1861748    9.04279  25.8%     -    2s
# H    0     0                      11.1963095    9.04279  19.2%     -    3s
#      0     0    9.07166    0  331   11.19631    9.07166  19.0%     -    4s
#      0     0    9.07454    0  332   11.19631    9.07454  19.0%     -    4s
#      0     0    9.07518    0  332   11.19631    9.07518  18.9%     -    4s
#      0     0    9.19505    0  317   11.19631    9.19505  17.9%     -    4s
#      0     0    9.22089    0  317   11.19631    9.22089  17.6%     -    4s
#      0     0    9.22089    0  307   11.19631    9.22089  17.6%     -    5s
# H    0     0                      11.1204464    9.22089  17.1%     -    5s
#      0     0    9.22089    0  307   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  306   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  306   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  307   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  307   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  292   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  300   11.12045    9.22089  17.1%     -    5s
#      0     0    9.22089    0  293   11.12045    9.22089  17.1%     -    6s
# H    0     0                      11.0225646    9.22089  16.3%     -    6s
#      0     0    9.22089    0  304   11.02256    9.22089  16.3%     -    6s
#      0     0    9.22089    0  306   11.02256    9.22089  16.3%     -    6s
#      0     0    9.22089    0  267   11.02256    9.22089  16.3%     -    6s
#      0     0    9.22089    0  259   11.02256    9.22089  16.3%     -    7s
#      0     0    9.23018    0  265   11.02256    9.23018  16.3%     -    7s
#      0     0    9.23018    0  276   11.02256    9.23018  16.3%     -    7s
#      0     0    9.23018    0  276   11.02256    9.23018  16.3%     -    7s
#      0     0    9.23018    0  261   11.02256    9.23018  16.3%     -    7s
#      0     0    9.23018    0  261   11.02256    9.23018  16.3%     -    7s
#      0     0    9.23018    0  261   11.02256    9.23018  16.3%     -    8s
#      0     0    9.23018    0  261   11.02256    9.23018  16.3%     -    8s
#      0     2    9.30982    0  261   11.02256    9.30982  15.5%     -    8s
#    117   128    9.35640   10  288   11.02256    9.30982  15.5%  52.8   10s
# H  127   138                      10.9831977    9.30982  15.2%  49.8   11s
# H  129   138                      10.9032497    9.30982  14.6%  49.1   11s
# H  132   138                      10.8919939    9.30982  14.5%  48.4   11s
# H  136   138                      10.8775389    9.30982  14.4%  47.3   11s
# H  537   533                      10.4138552    9.30982  10.6%  24.5   15s
# H  538   533                      10.4115234    9.30982  10.6%  24.5   15s
# H  542   533                      10.2906985    9.30982  9.53%  24.6   15s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 1
#   Implied bound: 88
#   MIR: 84
#   GUB cover: 2
#   Zero half: 4
#   Mod-K: 4
#   RLT: 47
#   Relax-and-lift: 66
#   BQP: 5
#   PSD: 7
#
# Explored 547 nodes (18076 simplex iterations) in 15.03 seconds (24.70 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 10.2907 10.4115 10.4139 ... 11.1963
#
# Time limit reached
# Best objective 1.029069847286e+01, best bound 9.309815069240e+00, gap 9.5317%
#
# User-callback calls 7974, time in user-callback 0.01 sec

# %% [markdown]
# ## The effect of strong branching

# %% [markdown]
# Let us try to turn on different variable selection policies, and see what happens. We will use the default cuts.

# %% [markdown]
# First, we try strong branching.

# %%
mdl_mtz_3 = TSPModel(dat, optimizer = optimizer_branch)
add_mtz_constraints!(mdl_mtz_3)
add_tracking_callback!(mdl_mtz_3)
solve!(mdl_mtz_3)
plot_progress([mdl_mtz, mdl_mtz_2, mdl_mtz_3], ["No Cuts", "Cuts", "Strong Branching"])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-18
# Set parameter VarBranch to value 3
# Set parameter TimeLimit to value 15
# Set parameter VarBranch to value 3
# Set parameter TimeLimit to value 15
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.3.0 23D56)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 45301 rows, 22650 columns and 156455 nonzeros
# Model fingerprint: 0xde9bd251
# Variable types: 150 continuous, 22500 integer (22500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [5e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 11774 rows and 151 columns
# Presolve time: 0.20s
# Presolved: 33527 rows, 22499 columns, 133206 nonzeros
# Variable types: 149 continuous, 22350 integer (22350 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.022202e+00, 662 iterations, 0.07 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0